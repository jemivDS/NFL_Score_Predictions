# %%
from sportsreference.nfl.boxscore import Boxscore
from sportsreference.nfl.schedule import Schedule

# %%
# houston_schedule = Schedule('HTX')
# for game in houston_schedule:
#     print(game.date)  # Prints the date the game was played
#     print(game.result)  # Prints whether the team won or lost
#     # Creates an instance of the Boxscore class for the game.
#     boxscore = game.boxscore
# Out:
# September 10
# Loss
# September 20
# Loss
# September 27
# Loss
# October 4
# Loss
# October 11
# Win
# October 18
# Loss
# October 25
# Loss
# November 8
# Win
# November 15
# Loss
# November 22
# Win
# November 26
# None
# December 6
# None
# December 13
# None
# December 20
# None
# December 27
# None
# January 3
# None

# %%
from sportsreference.nfl.boxscore import Boxscores
import pandas as pd
import numpy as np

## Create range of yeard from 1990 to 2018 and weeks from 1 to 17 (i.e. Regular Season)
years = list(np.arange(1990, 2019,1))
weeks = list(np.arange(1,18,1))



boxes = []
hometeam = []
awayteam = []
homescore = []
awayscore = []

for yr in years:
    for week in weeks:
        game = Boxscores(week, yr)
        
        games_sub = game.games
        key1 = list(games_sub.keys())[0]
        dict1 = games_sub[key1]
        for k in range(len(dict1)):
            dict2 = dict1[k]
            
            boxes.append(dict2['boxscore'])
            
            hometeam.append(dict2['home_name'])
            awayteam.append(dict2['away_name'])
            
            homescore.append(dict2['home_score'])
            awayscore.append(dict2['away_score'])

# %%
boxes1 = pd.DataFrame({
    'box_key':boxes, 
    'home_team':hometeam, 
    'away_team':awayteam, 
    'home_score':homescore,
    'away_score':awayscore})        

keys = list(boxes1['box_key'])

# %%
date = []
time = []
stadium = []
attendance = []
duration = []
away_name = []
home_name = []
winner = []
winning_name = []
losing_name = []
summary = []
away_points = []
away_first_downs = []
away_rush_attempts = []
away_rush_yards = []
away_rush_touchdowns = []
away_pass_completions = []
away_pass_attempts = []
away_pass_yards = []
away_pass_touchdowns = []
away_interceptions = []
away_times_sacked = []
away_yards_lost_from_sacks = []
away_net_pass_yards = []
away_total_yards = []
away_fumbles = []
away_fumbles_lost = []
away_turnovers = []
away_penalties = []
away_yards_from_penalties = []
away_third_down_conversions = []
away_third_down_attempts = []
away_fourth_down_conversions = []
away_fourth_down_attempts = []
away_time_of_possession = []
home_points = []
home_first_downs = []
home_rush_attempts = []
home_rush_yards = []
home_rush_touchdowns = []
home_pass_completions = []
home_pass_attempts = []
home_pass_yards = []
home_pass_touchdowns = []
home_interceptions = []
home_times_sacked = []
home_yards_lost_from_sacks = []
home_net_pass_yards = []
home_total_yards = []
home_fumbles = []
home_fumbles_lost = []
home_turnovers = []
home_penalties = []
home_yards_from_penalties = []
home_third_down_conversions = []
home_third_down_attempts = []
home_fourth_down_conversions = []
home_fourth_down_attempts = []
home_time_of_possession = []

for i in range(len(keys)):
    bs = Boxscore(keys[i])
    date.append(bs.date)
    time.append(bs.time)
    stadium.append(bs.stadium)
    attendance.append(bs.attendance)
    duration.append(bs.duration)
    winner.append(bs.winner)
    winning_name.append(bs.winning_name)
    losing_name.append(bs.losing_name)
    summary.append(bs.summary)
    away_points.append(bs.away_points)
    away_first_downs.append(bs.away_first_downs)
    away_rush_attempts.append(bs.away_rush_attempts)
    away_rush_yards.append(bs.away_rush_yards)
    away_rush_touchdowns.append(bs.away_rush_touchdowns)
    away_pass_completions.append(bs.away_pass_completions)
    away_pass_attempts.append(bs.away_pass_attempts)
    away_pass_yards.append(bs.away_pass_yards)
    away_pass_touchdowns.append(bs.away_pass_touchdowns)
    away_interceptions.append(bs.away_interceptions)
    away_times_sacked.append(bs.away_times_sacked)
    away_yards_lost_from_sacks.append(bs.away_yards_lost_from_sacks)
    away_net_pass_yards.append(bs.away_net_pass_yards)
    away_total_yards.append(bs.away_total_yards)
    away_fumbles.append(bs.away_fumbles)
    away_fumbles_lost.append(bs.away_fumbles_lost)
    away_turnovers.append(bs.away_turnovers)
    away_penalties.append(bs.away_penalties)
    away_yards_from_penalties.append(bs.away_yards_from_penalties)
    away_third_down_conversions.append(bs.away_third_down_conversions)
    away_third_down_attempts.append(bs.away_third_down_attempts)
    away_fourth_down_conversions.append(bs.away_fourth_down_conversions)
    away_fourth_down_attempts.append(bs.away_fourth_down_attempts)
    away_time_of_possession.append(bs.away_time_of_possession)
    home_points.append(bs.home_points)
    home_first_downs.append(bs.home_first_downs)
    home_rush_attempts.append(bs.home_rush_attempts)
    home_rush_yards.append(bs.home_rush_yards)
    home_rush_touchdowns.append(bs.home_rush_touchdowns)
    home_pass_completions.append(bs.home_pass_completions)
    home_pass_attempts.append(bs.home_pass_attempts)
    home_pass_yards.append(bs.home_pass_yards)
    home_pass_touchdowns.append(bs.home_pass_touchdowns)
    home_interceptions.append(bs.home_interceptions)
    home_times_sacked.append(bs.home_times_sacked)
    home_yards_lost_from_sacks.append(bs.home_yards_lost_from_sacks)
    home_net_pass_yards.append(bs.home_net_pass_yards)
    home_total_yards.append(bs.home_total_yards)
    home_fumbles.append(bs.home_fumbles)
    home_fumbles_lost.append(bs.home_fumbles_lost)
    home_turnovers.append(bs.home_turnovers)
    home_penalties.append(bs.home_penalties)
    home_yards_from_penalties.append(bs.home_yards_from_penalties)
    home_third_down_conversions.append(bs.home_third_down_conversions)
    home_third_down_attempts.append(bs.home_third_down_attempts)
    home_fourth_down_conversions.append(bs.home_fourth_down_conversions)
    home_fourth_down_attempts.append(bs.home_fourth_down_attempts)
    home_time_of_possession.append(bs.home_time_of_possession)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...

# %%
l = [date,
    time,
    stadium,
    attendance,
    duration,
    winner,
    winning_name,
    losing_name,
    summary,
    away_points,
    away_first_downs,
    away_rush_attempts,
    away_rush_yards,
    away_rush_touchdowns,
    away_pass_completions,
    away_pass_attempts,
    away_pass_yards,
    away_pass_touchdowns,
    away_interceptions,
    away_times_sacked,
    away_yards_lost_from_sacks,
    away_net_pass_yards,
    away_total_yards,
    away_fumbles,
    away_fumbles_lost,
    away_turnovers,
    away_penalties,
    away_yards_from_penalties,
    away_third_down_conversions,
    away_third_down_attempts,
    away_fourth_down_conversions,
    away_fourth_down_attempts,
    away_time_of_possession,
    home_points,
    home_first_downs,
    home_rush_attempts,
    home_rush_yards,
    home_rush_touchdowns,
    home_pass_completions,
    home_pass_attempts,
    home_pass_yards,
    home_pass_touchdowns,
    home_interceptions,
    home_times_sacked,
    home_yards_lost_from_sacks,
    home_net_pass_yards,
    home_total_yards,
    home_fumbles,
    home_fumbles_lost,
    home_turnovers,
    home_penalties,
    home_yards_from_penalties,
    home_third_down_conversions,
    home_third_down_attempts,
    home_fourth_down_conversions,
    home_fourth_down_attempts,
    home_time_of_possession]

# %%
df = pd.DataFrame(index = np.arange(len(l[0])), columns= np.arange(len(l)))

for i in range(len(l)):
    df.iloc[:,i] = l[i]
    
df
# Out:
#                          0       1                                   2   \
# 0        Sunday Sep 9, 1990  1:00pm                       Soldier Field
# 1        Sunday Sep 9, 1990  1:00pm  Robert F. Kennedy Memorial Stadium
# 2        Sunday Sep 9, 1990  1:00pm                   Arrowhead Stadium
# 3        Sunday Sep 9, 1990  1:00pm                       Lambeau Field
# 4        Sunday Sep 9, 1990  1:00pm                  Pontiac Silverdome
# ...                     ...     ...                                 ...
# 5399    Sunday Sep 16, 2012  4:25pm                         Heinz Field
# 5400    Sunday Sep 16, 2012  8:30pm                    Candlestick Park
# 5401    Monday Sep 17, 2012  8:41pm                        Georgia Dome
# 5402  Thursday Sep 20, 2012  8:20pm             Bank of America Stadium
# 5403    Sunday Sep 23, 2012  1:02pm            Cleveland Browns Stadium
#
#            3     4     5                     6                  7   \
# ...

# %%
len(unique(keys))
# Out:
# 7162

# %%
df.to_csv(r'C:\Users\jemcg\OneDrive\Desktop\Grad School\Classes\Fall 2020\Sports\nfl_historical_data.csv', index=False)

# %%
df_cols = pd.read_csv(r'C:\Users\jemcg\OneDrive\Desktop\Grad School\Classes\Fall 2020\Sports\nfl_historical_data_columns_added_upto_2012.csv')
df_cols
# Out:
#                        date    time                             stadium  \
# 0        Sunday Sep 9, 1990  1:00pm                       Soldier Field
# 1        Sunday Sep 9, 1990  1:00pm  Robert F. Kennedy Memorial Stadium
# 2        Sunday Sep 9, 1990  1:00pm                   Arrowhead Stadium
# 3        Sunday Sep 9, 1990  1:00pm                       Lambeau Field
# 4        Sunday Sep 9, 1990  1:00pm                  Pontiac Silverdome
# ...                     ...     ...                                 ...
# 5399    Sunday Sep 16, 2012  4:25pm                         Heinz Field
# 5400    Sunday Sep 16, 2012  8:30pm                    Candlestick Park
# 5401    Monday Sep 17, 2012  8:41pm                        Georgia Dome
# 5402  Thursday Sep 20, 2012  8:20pm             Bank of America Stadium
# 5403    Sunday Sep 23, 2012  1:02pm            Cleveland Browns Stadium
#
#       attendance duration winner          winning_name        losing_name  \
# ...

# %%
pd.options.mode.chained_assignment = None  # default='warn'

df_cols_nonan = df_cols[df_cols.columns[~df_cols.isnull().any()]]
cols_nonan = []

    
df_cols_nonan['total_yards'] = df_cols_nonan['away_total_yards']+df_cols_nonan['home_total_yards']
df_cols_nonan['total_rush_yards'] = df_cols_nonan['away_rush_yards']+df_cols_nonan['home_rush_yards']
df_cols_nonan['total_pass_yards'] = df_cols_nonan['away_pass_yards']+df_cols_nonan['home_pass_yards']
df_cols_nonan

for col in df_cols_nonan:
    cols_nonan.append(col)
    
df_cols_nonan['date'] = pd.to_datetime(df_cols_nonan['date'])

df_cols_nonan['rush_yards_pct'] = df_cols_nonan['total_rush_yards'] / df_cols_nonan['total_yards']
df_cols_nonan['pass_yards_pct'] = df_cols_nonan['total_pass_yards']/df_cols_nonan['total_yards']

df_cols_nonan
# Out:
#            date    time                             stadium winner  \
# 0    1990-09-09  1:00pm                       Soldier Field   Home
# 1    1990-09-09  1:00pm  Robert F. Kennedy Memorial Stadium   Home
# 2    1990-09-09  1:00pm                   Arrowhead Stadium   Home
# 3    1990-09-09  1:00pm                       Lambeau Field   Home
# 4    1990-09-09  1:00pm                  Pontiac Silverdome   Away
# ...         ...     ...                                 ...    ...
# 5399 2012-09-16  4:25pm                         Heinz Field   Home
# 5400 2012-09-16  8:30pm                    Candlestick Park   Home
# 5401 2012-09-17  8:41pm                        Georgia Dome   Home
# 5402 2012-09-20  8:20pm             Bank of America Stadium   Away
# 5403 2012-09-23  1:02pm            Cleveland Browns Stadium   Away
#
#               winning_name        losing_name  \
# 0            Chicago Bears   Seattle Seahawks
# 1      Washington Redskins  Phoenix Cardinals
# ...

# %%
df_cols_nonan['year'] = df_cols_nonan['date'].apply(lambda x: x.year)
df_cols_nonan['month'] = df_cols_nonan['date'].apply(lambda x: x.month)

df_gb = pd.DataFrame(df_cols_nonan.groupby(['year', 'month'])[['pass_yards_pct', 'rush_yards_pct']].mean()).reset_index()


df_gb['combined']=df_gb.apply(lambda x:'%i-%i' % (x['month'],x['year']),axis=1)
df_gb['combined'] = pd.to_datetime(df_gb['combined'])
df_gb
# Out:
#     year  month  pass_yards_pct  rush_yards_pct   combined
# 0   1990      9        0.704567        0.357139 1990-09-01
# 1   1990     10        0.701220        0.355811 1990-10-01
# 2   1990     11        0.665446        0.395682 1990-11-01
# 3   1990     12        0.656634        0.392891 1990-12-01
# 4   1991      9        0.681566        0.372910 1991-09-01
# ..   ...    ...             ...             ...        ...
# 92  2011     10        0.692925        0.354979 2011-10-01
# 93  2011     11        0.691613        0.349527 2011-11-01
# 94  2011     12        0.691435        0.358876 2011-12-01
# 95  2012      1        0.690919        0.351839 2012-01-01
# 96  2012      9        0.732366        0.311638 2012-09-01
#
# [97 rows x 5 columns]

# %%
df_gb_yr = pd.DataFrame(df_cols_nonan.groupby(['year'])[['pass_yards_pct', 'rush_yards_pct']].mean()).reset_index()
df_gb_yr
# Out:
#     year  pass_yards_pct  rush_yards_pct
# 0   1990        0.679853        0.376993
# 1   1991        0.695091        0.359589
# 2   1992        0.684494        0.379343
# 3   1993        0.686379        0.363942
# 4   1994        0.709378        0.336789
# 5   1995        0.711882        0.335762
# 6   1996        0.699299        0.350044
# 7   1997        0.695863        0.362833
# 8   1998        0.694107        0.359911
# 9   1999        0.711611        0.342824
# 10  2000        0.693062        0.357264
# 11  2001        0.693378        0.356626
# 12  2002        0.688030        0.360576
# 13  2003        0.668648        0.375933
# 14  2004        0.681886        0.366870
# 15  2005        0.687027        0.362115
# 16  2006        0.677050        0.371220
# 17  2007        0.698580        0.347073
# 18  2008        0.682182        0.359826
# 19  2009        0.692234        0.352230
# 20  2010        0.695685        0.349339
# 21  2011        0.701466        0.345918
# ...

# %%
import matplotlib.pyplot as plt

clrs = ['#013369', '#D50A0A']
plt.figure(figsize = [15,5])
def subcategorybar(X, vals, width=0.8):
    n = len(vals)
    _X = np.arange(len(X))
    for i in range(n):
        plt.bar(_X - width/2. + i/float(n)*width, vals[i], 
                width=width/float(n), align="edge", color=clrs[i]) 
    plt.xticks(_X, X)
    
subcategorybar(df_gb_yr['year'], [df_gb_yr['pass_yards_pct'], df_gb_yr['rush_yards_pct']])
plt.title('Percentage of Rush and Pass Yards vs. Total Yards, 1990-2012')
plt.xlabel('Year')
plt.ylim(0,1)
plt.legend(['Pass Yards Pct.', 'Rush Yards Pct.'])
plt.show()
